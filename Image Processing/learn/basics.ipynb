# %%
from skimage import io
import pandas as pd

# %%
img = io.imread('photo2.jpg')
df = pd.DataFrame(img.flatten())

# %%
io.imshow(img)

# %%
from skimage import color
from skimage import data
from pylab import *

# %%
img_hsv = color.rgb2hsv(img)

# %%
io.imshow(img_hsv)

# %%
from skimage import exposure

# %%
gamma_corrected1 = exposure.adjust_gamma(img, 0.5)
gamma_corrected2 = exposure.adjust_gamma(img, 5)

# %%
figure(0)
io.imshow(gamma_corrected1)
figure(1)
io.imshow(gamma_corrected2)

# %%
import cv2
import numpy as np

# %%
image_MedianBlur=cv2.medianBlur(img,9)
image_GaussianBlur=cv2.GaussianBlur(img,(9,9),10)
image_BilateralBlur=cv2.bilateralFilter(img,9, 100,75)

# %%
figure(0)
io.imshow(img)
figure(1)
io.imshow(image_MedianBlur)
figure(2)
io.imshow(image_GaussianBlur)
figure(3)
io.imshow(image_BilateralBlur)

# %%
_, img1 = cv2.threshold(img, 50, 255, 0 )
_, img2 = cv2.threshold(img, 50, 255, 1 )
_, img3 = cv2.threshold(img, 50, 255, 2 )
_, img4 = cv2.threshold(img, 50, 255, 3 )
_, img5 = cv2.threshold(img, 50, 255, 4 )
#Show the different threshold images
figure(0)
io.imshow(img1) #Prints Binary Image
figure(1)
io.imshow(img2) #Prints Binary Inverted Image
figure(2)
io.imshow(img3) #Prints Truncated Image
figure(3)
io.imshow(img4) #Prints Threshold to Zero Image
figure(4)
io.imshow(img5) #Prints Threshold to Zero Inverted Image

# %%
cv2.GaussianBlur(img, (3, 3), 0)
#Convert image to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#Apply Sobel method to the grayscale image
grad_x = cv2.Sobel(gray, cv2.CV_16S, 1, 0, ksize=3, scale=1, 
delta=0, borderType=cv2.BORDER_DEFAULT) #Horizontal Sobel 

grad_y = cv2.Sobel(gray, cv2.CV_16S, 0, 1, ksize=3, scale=1, 
delta=0, borderType=cv2.BORDER_DEFAULT) #Vertical Sobel 

abs_grad_x = cv2.convertScaleAbs(grad_x)
abs_grad_y = cv2.convertScaleAbs(grad_y)
grad = cv2.addWeighted(abs_grad_x, 0.5, abs_grad_y, 0.5, 0) 
#Apply both
#Show the image
io.imshow(grad)#View the image

# %%
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#Apply equalize histogram
src_eqlzd = cv2.equalizeHist(img) #Performs Histogram Equalization
#Show both images
figure(0)
io.imshow(img)
figure(1)
io.imshow(src_eqlzd)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8048/3668045962.py in <module>
#       1 src = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#       2 #Apply equalize histogram
# ----> 3 src_eqlzd = cv2.equalizeHist(img) #Performs Histogram Equalization
#       4 #Show both images
#       5 figure(0)
#
# error: OpenCV(4.5.3) C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-sn_xpupm\opencv\modules\imgproc\src\histogram.cpp:3439: error: (-215:Assertion failed) _src.type() == CV_8UC1 in function 'cv::equalizeHist'
